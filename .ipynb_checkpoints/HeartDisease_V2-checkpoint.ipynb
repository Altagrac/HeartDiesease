# %% [markdown]
# # Heart Failure Prediction Dataset : VERSION_2
#
# **Objectif** : Identifier une possible défaillance cardiaque chez l'individu

# %% [markdown]
# ### Packages necessaires & dataset

# %%
import sys 
#sys.path.insert(0, "C://Users/asnga/KatalyseGits/mypackage")
sys.path.append("../")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %matplotlib inline
from mypackage.functions import *
from mypackage.classifcationmodels import *
from mypackage.encoding_functions import *
from mypackage.opersfunctions import *

# from sklearn.impute import SimpleImputer
# from sklearn.datasets import make_classification, load_iris
# from sklearn.pipeline import make_pipeline
# from sklearn.compose import make_column_transformer,make_column_selector
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder,RobustScaler
# from sklearn.tree import export_graphviz, DecisionTreeClassifier, plot_tree

# %%
#Data retrieving  
HeartD_df = pd.read_csv("heart.csv")

# %%
#df : deep copy of initial dataset
df = HeartD_df.copy()

# %% [markdown]
# ### Analyse de forme:

# %%
# # # to show all the rows of the dataset
pd.set_option('display.max_row',df.shape[0])

# # # to show all the columns of the dataset
pd.set_option('display.max_columns',df.shape[1])

# %%
# #First row of the dataset 
df.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# - **Analyse Target :**
#
#  variable target : **HeartDisease**

# %% [markdown]
# - **Rows & columns :**

# %%
dshape(df)
# Out:
# This dataset contains:
# --> 918 lignes
# --> 12 colones
# --> RangeIndex(start=0, stop=918, step=1)

# %% [markdown]
# - **Vairables types :**

# %%
data_types(df)
# Out:
# (  Numerics_cols Categorials_cols
#  0           Age              Sex
#  1     RestingBP    ChestPainType
#  2   Cholesterol       RestingECG
#  3     FastingBS   ExerciseAngina
#  4         MaxHR         ST_Slope
#  5       Oldpeak              NaN
#  6  HeartDisease              NaN,
#  <AxesSubplot: >)

# %% [markdown]
# - **Some statistics on numerics variables :**

# %%
stats(df)
# Out:
#                     mean     25%    50%    75%  count
# Age            53.510893   47.00   54.0   60.0  918.0
# RestingBP     132.396514  120.00  130.0  140.0  918.0
# Cholesterol   198.799564  173.25  223.0  267.0  918.0
# FastingBS       0.233115    0.00    0.0    0.0  918.0
# MaxHR         136.809368  120.00  138.0  156.0  918.0
# Oldpeak         0.887364    0.00    0.6    1.5  918.0
# HeartDisease    0.553377    0.00    1.0    1.0  918.0

# %%
df.describe(include="all").T
# Out:
#                 count unique     top freq        mean         std   min  \
# Age             918.0    NaN     NaN  NaN   53.510893    9.432617  28.0
# Sex               918      2       M  725         NaN         NaN   NaN
# ChestPainType     918      4     ASY  496         NaN         NaN   NaN
# RestingBP       918.0    NaN     NaN  NaN  132.396514   18.514154   0.0
# Cholesterol     918.0    NaN     NaN  NaN  198.799564  109.384145   0.0
# FastingBS       918.0    NaN     NaN  NaN    0.233115    0.423046   0.0
# RestingECG        918      3  Normal  552         NaN         NaN   NaN
# MaxHR           918.0    NaN     NaN  NaN  136.809368   25.460334  60.0
# ExerciseAngina    918      2       N  547         NaN         NaN   NaN
# Oldpeak         918.0    NaN     NaN  NaN    0.887364     1.06657  -2.6
# ST_Slope          918      3    Flat  460         NaN         NaN   NaN
# HeartDisease    918.0    NaN     NaN  NaN    0.553377    0.497414   0.0
#
#                    25%    50%    75%    max
# Age               47.0   54.0   60.0   77.0
# Sex                NaN    NaN    NaN    NaN
# ChestPainType      NaN    NaN    NaN    NaN
# RestingBP        120.0  130.0  140.0  200.0
# Cholesterol     173.25  223.0  267.0  603.0
# FastingBS          0.0    0.0    0.0    1.0
# RestingECG         NaN    NaN    NaN    NaN
# MaxHR            120.0  138.0  156.0  202.0
# ExerciseAngina     NaN    NaN    NaN    NaN
# Oldpeak            0.0    0.6    1.5    6.2
# ST_Slope           NaN    NaN    NaN    NaN
# HeartDisease       0.0    1.0    1.0    1.0

# %% [markdown]
# - **Analyse of missing values :**

# %%
map_nan(df)

# %%
percentage_mv(df)
# Out:
# Percentage of missing values by columns
# Age               0.0
# Sex               0.0
# ChestPainType     0.0
# RestingBP         0.0
# Cholesterol       0.0
# FastingBS         0.0
# RestingECG        0.0
# MaxHR             0.0
# ExerciseAngina    0.0
# Oldpeak           0.0
# ST_Slope          0.0
# HeartDisease      0.0
# dtype: float64

# %% [markdown]
# ### Analyse de fond (Préparation des données)

# %% [markdown]
# - **Visualisation de la target :**

# %%
info_target(df,"HeartDisease")
# Out:
# Target values & percentage by categorie
#
#    HeartDisease
# 1           508
# 0           410
#    HeartDisease
# 1      0.553377
# 0      0.446623

# %% [markdown]
# - **Analyse des Variables Continues :**

# %%
plot_num(df)

# %% [markdown]
# - **Analyse des Variables Discrètes :**

# %%
plot_cat(df)

# %%
ditrib_df(df)

# %% [markdown]
# - **Signification des variables :**

# %% [markdown]
# - **Relation Variables / Target :**
#     - Création de sous-ensembles: heartdisease(1) & notheartdisease(1)

# %%
# target_yes = df[df["HeartDisease"] == 1]  
# target_no = df[df["HeartDisease"] == 0]

# %%
#df['Cholesterol_measure'] =  df.apply(lambda x: np.where(x["Cholesterol"] > 0, 1, 0) , axis=1)

# %% [markdown]
#    - Analyse Target / concat ( cat+num)
#     - Analyse Target / Variables categorielles
#     - Analyse Target / Variables numeriques

# %% [markdown]
# ### Conclusions de base:
#        Ce jeu de données ne possedent pas de valeurs manquantes, avec une majorité de valeurs hommes que femmes.

# %% [markdown]
# ### **Preprocessing**

# %% [markdown]
# **Preparing dataset into train & test samples**

# %%
#extraction de la cible(y) et des variables explicatives(X)
y=df["HeartDisease"]
X=df.drop(["HeartDisease"],axis=1)

# %%
#séparation des données : données d'entrainement & données de test 
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %% [markdown]
# ### _Première itération_ : Encodages de features
#
# **Encodage _1**
#         . Traitement des variables catégorielles : OneHotEncoder()
#         . Traitement des variables numériques : RobustSclaer()

# %%
# Encoding training Dataset  
X1_train = pd.concat([nums_values(X_train,X_train, RobustScaler()),
                      encode_cat_values(X_train, X_train, OneHotEncoder())],axis=1)

# %%
# Encoding test Dataset 
X1_test = pd.concat([nums_values(X_train,X_test, RobustScaler()),
                      encode_cat_values(X_train, X_test, OneHotEncoder())],axis=1)

# %% [markdown]
# **Modelisation_1**

# %%
clas_ml(X1_train, y_train, X1_test, y_test)
# Out:
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# 'DONE!!!'

# %%
eval_report(y_test)
# Out:
#  MODELS EVALUATION REPORT
# ........................
#                    Accuracy  Precision  Sensitivity_recall  Specificity  \
# Nearest Neighbors  0.855072   0.863905            0.895706     0.796460
# Linear SVM         0.829710   0.853659            0.858896     0.787611
# RBF SVM            0.735507   0.695652            0.981595     0.380531
# Gaussian Process   0.862319   0.865497            0.907975     0.796460
# Decision Tree      0.840580   0.865031            0.865031     0.805310
# Random Forest      0.793478   0.839744            0.803681     0.778761
# AdaBoost           0.862319   0.878788            0.889571     0.823009
# Naive Bayes        0.855072   0.868263            0.889571     0.805310
#
#                    F1_score
# Nearest Neighbors  0.879518
# Linear SVM         0.856269
# RBF SVM            0.814249
# Gaussian Process   0.886228
# Decision Tree      0.865031
# Random Forest      0.821317
# AdaBoost           0.884146
# Naive Bayes        0.878788

# %%
conf_matrix(y_test)
# Out:
#  CONFUSION MATRIX BY MODEL
# ........................

# %% [markdown]
# **Encodage _2**
#         . Traitement des variables catégorielles : OneHotEncoder()
#         . Traitement des variables numériques : StandardSclaer()

# %%
# Encoding training Dataset  
X2_train = pd.concat([nums_values(X_train,X_train, StandardScaler()),
                      encode_cat_values(X_train, X_train, OneHotEncoder())],axis=1)

# %%
# Encoding test Dataset 
X2_test = pd.concat([nums_values(X_train,X_test, StandardScaler()),
                      encode_cat_values(X_train, X_test, OneHotEncoder())],axis=1)

# %% [markdown]
# **Modelisation_2**

# %%
clas_ml(X2_train, y_train, X2_test, y_test)
# Out:
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# 'DONE!!!'

# %%
eval_report(y_test)
# Out:
#  MODELS EVALUATION REPORT
# ........................
#                    Accuracy  Precision  Sensitivity_recall  Specificity  \
# Nearest Neighbors  0.858696   0.882716            0.877301     0.831858
# Linear SVM         0.840580   0.860606            0.871166     0.796460
# RBF SVM            0.699275   0.666667            0.981595     0.292035
# Gaussian Process   0.855072   0.863905            0.895706     0.796460
# Decision Tree      0.840580   0.869565            0.858896     0.814159
# Random Forest      0.847826   0.853801            0.895706     0.778761
# AdaBoost           0.862319   0.878788            0.889571     0.823009
# Naive Bayes        0.855072   0.868263            0.889571     0.805310
#
#                    F1_score
# Nearest Neighbors  0.880000
# Linear SVM         0.865854
# RBF SVM            0.794045
# Gaussian Process   0.879518
# Decision Tree      0.864198
# Random Forest      0.874251
# AdaBoost           0.884146
# Naive Bayes        0.878788

# %%
conf_matrix(y_test)
# Out:
#  CONFUSION MATRIX BY MODEL
# ........................

# %% [markdown]
# ### _Deuxième itération_ : Selection  de features

# %% [markdown]
# ####   **Methode 1 :**
#    - Création de sous-ensembles: nouvelle colone pour taux_cholesterol infé à 0 <==>
#      cholesterol_rate = 0 :: non measure , new_col <=> choles_rate measure = O for no & 1 for yes ,
#         function apply to use

# %%
df_new = df.copy()

# %%
df_new['Cholesterol_measure'] =  (df_new[["Cholesterol"]].sum(axis=1) > 0).astype(int)

# %%
df_new.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS  ... MaxHR  \
# 0   40   M           ATA        140          289          0  ...   172
# 1   49   F           NAP        160          180          0  ...   156
# 2   37   M           ATA        130          283          0  ...    98
# 3   48   F           ASY        138          214          0  ...   108
# 4   54   M           NAP        150          195          0  ...   122
#
#    ExerciseAngina Oldpeak  ST_Slope HeartDisease  Cholesterol_measure
# 0               N     0.0        Up            0                    1
# 1               N     1.0      Flat            1                    1
# 2               N     0.0        Up            0                    1
# 3               Y     1.5      Flat            1                    1
# 4               N     0.0        Up            0                    1
#
# [5 rows x 13 columns]

# %%
y_op = df_new["HeartDisease"]
X_op = df_new.drop(["HeartDisease"],axis=1)

# %%
#séparation des données : données d'entrainement & données de test 
X_op_train,X_op_test,y_op_train,y_op_test = train_test_split(X_op, y_op, test_size=0.30, random_state=0)

# %%
X1_op_train = pd.concat([nums_values(X_op_train,X_op_train, StandardScaler()),
                      encode_cat_values(X_op_train, X_op_train, OneHotEncoder())],axis=1)

# %%
X1_op_test = pd.concat([nums_values(X_op_train,X_op_test, StandardScaler()),
                        encode_cat_values(X_op_train, X_op_test, OneHotEncoder())],axis=1)

# %%
clas_ml(X1_op_train, y_op_train, X1_op_test, y_op_test)
# Out:
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# 'DONE!!!'

# %%
eval_report(y_test)
# Out:
#  MODELS EVALUATION REPORT
# ........................
#                    Accuracy  Precision  Sensitivity_recall  Specificity  \
# Nearest Neighbors  0.847826   0.875776            0.865031     0.823009
# Linear SVM         0.858696   0.864706            0.901840     0.796460
# RBF SVM            0.699275   0.666667            0.981595     0.292035
# Gaussian Process   0.855072   0.863905            0.895706     0.796460
# Decision Tree      0.836957   0.868750            0.852761     0.814159
# Random Forest      0.844203   0.857143            0.883436     0.787611
# AdaBoost           0.862319   0.878788            0.889571     0.823009
# Naive Bayes        0.858696   0.873494            0.889571     0.814159
#
#                    F1_score
# Nearest Neighbors  0.870370
# Linear SVM         0.882883
# RBF SVM            0.794045
# Gaussian Process   0.879518
# Decision Tree      0.860681
# Random Forest      0.870091
# AdaBoost           0.884146
# Naive Bayes        0.881459

# %%
conf_matrix(y_test)
# Out:
#  CONFUSION MATRIX BY MODEL
# ........................

# %% [markdown]
# #### **Methode 2:**
# - Suppresion des colones :
#     - ExerciceAngina
#     - FastingBS

# %%
X_op.head(3)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
#
#   ExerciseAngina  Oldpeak ST_Slope  Cholesterol_measure
# 0              N      0.0       Up                    1
# 1              N      1.0     Flat                    1
# 2              N      0.0       Up                    1

# %%
X_op2 = X_op.drop(["ExerciseAngina", "FastingBS"],axis = 1)

# %%
#séparation des données : données d'entrainement & données de test 
X_op2_train,X_op2_test,y_op2_train,y_op2_test = train_test_split(X_op2, y_op, test_size=0.30, random_state=0)

# %%
X2_op_train = pd.concat([nums_values(X_op2_train,X_op2_train, StandardScaler()),
                      encode_cat_values(X_op_train, X_op_train, OneHotEncoder())],axis=1)
#***
X2_op_test = pd.concat([nums_values(X_op2_train,X_op2_test, StandardScaler()),
                        encode_cat_values(X_op_train, X_op_test, OneHotEncoder())],axis=1)

# %%
clas_ml(X2_op_train, y_op_train, X2_op_test, y_op_test)
# Out:
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\asnga\anaconda3\envs\katalyse\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# 'DONE!!!'

# %%
eval_report(y_op_test)
# Out:
#  MODELS EVALUATION REPORT
# ........................
#                    Accuracy  Precision  Sensitivity_recall  Specificity  \
# Nearest Neighbors  0.873188   0.872093            0.920245     0.805310
# Linear SVM         0.847826   0.853801            0.895706     0.778761
# RBF SVM            0.717391   0.683983            0.969325     0.353982
# Gaussian Process   0.851449   0.854651            0.901840     0.778761
# Decision Tree      0.836957   0.868750            0.852761     0.814159
# Random Forest      0.844203   0.848837            0.895706     0.769912
# AdaBoost           0.833333   0.854545            0.865031     0.787611
# Naive Bayes        0.862319   0.874251            0.895706     0.814159
#
#                    F1_score
# Nearest Neighbors  0.895522
# Linear SVM         0.874251
# RBF SVM            0.802030
# Gaussian Process   0.877612
# Decision Tree      0.860681
# Random Forest      0.871642
# AdaBoost           0.859756
# Naive Bayes        0.884848

# %%
conf_matrix(y_op_test)
# Out:
#  CONFUSION MATRIX BY MODEL
# ........................

# %% [markdown]
# #### Methode 3 : Selection  de features

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
#    - **Feature :ChesPainType**
#
#    Le graphique de cette variable monter des outliers aussi, on va supprimer ces outliers.

# %%
outliers

# %%
df2.groupby(["Sex"]).count()
# Out:
#      Age  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# Sex
# F    193            193        193          193        193         193    193
# M    725            725        725          725        725         725    725
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# Sex
# F               193      193       193           193
# M               725      725       725           725

# %%
df2["ChestPainType"].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64
